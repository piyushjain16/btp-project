# %%
print("hello")
# Out:
# hello

# %%
import cv2

# %%
import logging

logging.basicConfig(filename="logging.log", filemode="w", format="%(levelname)s: %(message)s",level=logging.INFO)

# logging.warning("warning")
logging.info("info")

# %%
# !python "E:\python\Zero-DCE-master\Zero-DCE_code\lowlight_train.py"
# Out:
# ^C
# Total training examples: 2002
# Loss at iteration 10 : 1.322676420211792
# Loss at iteration 20 : 0.8455703258514404
# Loss at iteration 30 : 1.0673445463180542
# Loss at iteration 40 : 0.8222963213920593
# Loss at iteration 50 : 0.9556549191474915
# Loss at iteration 60 : 0.8969852924346924
# Loss at iteration 70 : 0.7085942029953003
# Loss at iteration 80 : 0.6606485843658447
# Loss at iteration 90 : 0.5298401117324829
# Loss at iteration 100 : 0.5718650817871094
# Loss at iteration 110 : 0.7229776382446289
# Loss at iteration 120 : 0.3153716027736664
# Loss at iteration 130 : 0.41397061944007874
# Loss at iteration 140 : 0.35808265209198
# Loss at iteration 150 : 0.5073554515838623
# Loss at iteration 160 : 0.7316415905952454
# Loss at iteration 170 : 0.4426027834415436
# Loss at iteration 180 : 0.6147258281707764
# Loss at iteration 190 : 0.45105835795402527
# Loss at iteration 200 : 0.4890281558036804
# Loss at iteration 210 : 0.4393375515937805
# ...

# %%
# !python "E:\python\Zero-DCE-master\Zero-DCE_code\lowlight_test.py"
# Out:
# PSNR : 27.367132017758834  SSIM : 0.5513138912346097
# PSNR : 27.37196566678579  SSIM : 0.538459183930334
# PSNR : 27.482244922794784  SSIM : 0.38451518037098364
# PSNR : 27.394595493957993  SSIM : 0.4043918418216599
# PSNR : 27.567307856157527  SSIM : 0.4621580573086186
# PSNR : 27.57529258284474  SSIM : 0.46110950593621375
# PSNR : 27.546354397816238  SSIM : 0.3387790377785522
# PSNR : 27.553609558421122  SSIM : 0.3343517300937266
# PSNR : 27.50061320161329  SSIM : 0.26682778524059525
# PSNR : 27.503897487145338  SSIM : 0.2612843415988865
# PSNR : 29.608982335261263  SSIM : 0.7055861008277504
# PSNR : 29.607395037035946  SSIM : 0.7125554573482812
# PSNR : 27.615540396127937  SSIM : 0.38998601807286515
# PSNR : 27.61469122641865  SSIM : 0.38951005305342135
# PSNR : 27.612925926249044  SSIM : 0.3869491908773686
# PSNR : 27.47143579841341  SSIM : 0.3051051582073424
# PSNR : 27.54560694377803  SSIM : 0.23506973144952992
# PSNR : 27.482173334571428  SSIM : 0.2994392548091115
# ...
